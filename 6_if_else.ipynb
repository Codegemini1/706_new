# %%
if 5 > 1:
    print('Right')
else:
    print('Wrong')
# Out:
# Right

# %%
if 5 < 1:
    print('True')
else:
    print('False')
# Out:
# False

# %%
marks = 80
if marks > 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Pass

# %%
age = int(input('Enter your age'))

if age > 18:
    print('You can drive a car')
else:
    print('You are not allowed to drive car')
# Out:
# Enter your age 6
# You are not allowed to drive car

# %%
time = int(input('Enter current time'))

if time > 10:
    print('Blunder in house')
else:
    print('Everything is fine in home')
# Out:
# Enter current time 11
# Blunder in house

# %%
marks = 35
if marks >= 35:
    print('pass')
else:
    print('Fail')
# Out:
# Fail

# %%
age = int(input('Enter your age'))

if age >= 18:
    print('You can drive a car')
else:
    print('You are not allowed to drive car')
# Out:
# Enter your age 18
# You can drive a car

# %%
marks = int(input('Marks'))

if marks >= 80:
    print('A+')
elif marks >= 50:
    print('B+')
elif marks >= 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Marks 65
# B+

# %%
marks = int(input('Marks'))

if marks >= 80:
    print('A+')
elif marks >= 50:
    print('B+')
elif marks >= 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Marks 150
# A+

# %%
marks = int(input('Marks'))

if marks>= 80 and marks < 100:
    print('A+')
elif marks >= 50 and marks < 80:
    print('B+')
elif marks  >= 35 and marks < 50:
    print('pass')
elif marks > 0 and marks < 35:
    print('Fail')
else:
    print('Please enter your marks b/w 0 - 100 range')
# Out:
# Marks 60
# B+

# %%
course = input('Enter a course name')

if course == 'python':
    print('Yes python course cost is 1000')
elif course == 'java':
    print('Yes course cost is 2000')
elif course == 'uiux':
    print('Yes uiux course cost is 3000')
else:
    print(f'Your course {course} is not avilable')
# Out:
# Enter a course name python
# Yes python course cost is 1000

# %%
tasks = []
time = int(input('Current time'))
cloths = input('Tell me your cloths are dirty or clean')
date = int(input('Write only first date '))

if time > 10:
    tasks.append('I have to buy milk')
elif cloths == 'dirty':
    tasks.append('Pikup cloths for cleaning')
elif data >= 15:
    tasks.append('Home Pay rent ')
# Out:
# Current time 11
# Tell me your cloths are dirty or clean dirt
# Write only first date  20

# %%
tasks
# Out:
# ['I have to buy milk']

# %%
tasks = []
time = int(input('Current time'))
cloths = input('Tell me your cloths are dirty or clean')
date = int(input('Write only first date '))

if time > 10:
    tasks.append('I have to buy milk')
else:
    print('No need to buy milk')


if cloths == 'dirty':
    tasks.append('Pikup cloths for cleaning')
else:
    print('No need to clean')


if data >= 15:
    tasks.append('Home Pay rent ')
else:
    print('')
