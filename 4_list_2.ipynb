# %%
l = [1,2,3,4,5,6,7,8]

# %%
l[3] = 400

# %%
l
# Out:
# [1, 2, 3, 400, 5, 6, 7, 8]

# %%
l[2:5]
# Out:
# [3, 400, 5]

# %%
l
# Out:
# [1, 2, 3, 400, 5, 6, 7, 8]

# %%
l[::-1]
# Out:
# [8, 7, 6, 5, 400, 3, 2, 1]

# %%
l
# Out:
# [1, 2, 3, 400, 5, 6, 7, 8]

# %%
l[3::-1]
# Out:
# [400, 3, 2, 1]

# %%
# functions

# %%
a = [1,2,3,4]

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
a.append(10)

# %%
a
# Out:
# [1, 2, 3, 4, 10]

# %%
a.append([100,200,300]) # append add as it is

# %%
a
# Out:
# [1, 2, 3, 4, 10, [100, 200, 300]]

# %%
a.extend([100, 200, 300]) # extend will add seperate elements

# %%
a
# Out:
# [1, 2, 3, 4, 10, [100, 200, 300], 100, 200, 300]

# %%
a.append('Hello')

# %%
a
# Out:
# [1, 2, 3, 4, 10, [100, 200, 300], 100, 200, 300, 'Hello']

# %%
a.extend('Hello')

# %%
a
# Out:
# [1,
#  2,
#  3,
#  4,
#  10,
#  [100, 200, 300],
#  100,
#  200,
#  300,
#  'Hello',
#  'H',
#  'e',
#  'l',
#  'l',
#  'o']

# %%
a.extend(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 a.extend(10)
#
# TypeError: 'int' object is not iterable

# %%
a.extend(True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 a.extend(True)
#
# TypeError: 'bool' object is not iterable

# %%
# diff b/w append and extend

# %%
l = [10,20,30]

# %%
l.remove(20)

# %%
l
# Out:
# [10, 30]

# %%
a.remove(10)

# %%
a
# Out:
# [1, 2, 3, 4, [100, 200, 300], 100, 200, 300, 'Hello', 'H', 'e', 'l', 'l', 'o']

# %%
d = [1,2,3,4,1,5,7,8,9]

# %%
d.remove(1)

# %%
d
# Out:
# [2, 3, 4, 1, 5, 7, 8, 9]

# %%
d.pop()
# Out:
# 9

# %%
d
# Out:
# [2, 3, 4, 1, 5, 7, 8]

# %%
d.pop()
# Out:
# 8

# %%
# inserting

# %%
d
# Out:
# [2, 3, 4, 1, 5, 7]

# %%
d.insert(1,300)

# %%
d
# Out:
# [2, 300, 3, 4, 1, 5, 7]

# %%
d
# Out:
# [2, 300, 3, 4, 1, 5, 7]

# %%
d.reverse()

# %%
d
# Out:
# [7, 5, 1, 4, 3, 300, 2]

# %%
d.index(300)
# Out:
# 5

# %%
a
# Out:
# [1, 2, 3, 4, [100, 200, 300], 100, 200, 300, 'Hello', 'H', 'e', 'l', 'l', 'o']

# %%
a.count('l')
# Out:
# 2

# %%
len(a)
# Out:
# 14

# %%
l
# Out:
# [10, 30]

# %%
k = [1,1,1,1,1,3,5]

# %%
a
# Out:
# [1, 2, 3, 4, [100, 200, 300], 100, 200, 300, 'Hello', 'H', 'e', 'l', 'l', 'o']

# %%
a[4].remove(200)

# %%
a
# Out:
# [1, 2, 3, 4, [100, 300], 100, 200, 300, 'Hello', 'H', 'e', 'l', 'l', 'o']

# %%
k
# Out:
# [1, 1, 1, 1, 1, 3, 5]

# %%
k.count(1)
# Out:
# 5

# %%
k.count(2)
# Out:
# 0

# %%
k.sort()

# %%
k
# Out:
# [1, 1, 1, 1, 1, 3, 5]

# %%
l
# Out:
# [10, 30]

# %%
a
# Out:
# [1, 2, 3, 4, [100, 300], 100, 200, 300, 'Hello', 'H', 'e', 'l', 'l', 'o']

# %%
a.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 a.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
n = [1,2,3,[10,20,30], 4]

# %%
n
# Out:
# [1, 2, 3, [10, 20, 30], 4]

# %%
n[3]
# Out:
# [10, 20, 30]

# %%
n[3][2]
# Out:
# 30

# %%
j = [1,2,3,[10,20, [100,200], 30], 4]

# %%
j[3]
# Out:
# [10, 20, [100, 200], 30]

# %%
j[3][2][1]
# Out:
# 200

# %%
j[3]
# Out:
# [10, 20, [100, 200], 30]

# %%
j[3][3]
# Out:
# 30

# %%
[1,1.5,'Hello',[10,10.2,'Python'], 2,True]
# Out:
# [1, 1.5, 'Hello', [10, 10.2, 'Python'], 2, True]

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
# Tuple ()

# %%
t = (1,2,3,4,5)

# %%
t[2]
# Out:
# 3

# %%
t[2] = 200
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 t[2] = 200
#
# TypeError: 'tuple' object does not support item assignment
