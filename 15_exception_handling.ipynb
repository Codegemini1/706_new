# %%
age = 50
if age > 90:
    print('Very old', age)
elif age > 60:
    print('Mid age',age)
elif age > 30:
    print('Young' + age)
elif age > 10 :
    print('Student')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5     print('Mid age',age)
#       6 elif age > 30:
# ----> 7     print('Young' + age)
#       8 elif age > 10 :
#       9     print('Student')
#
# TypeError: can only concatenate str (not "int") to str

# %%
3/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 3/0
#
# ZeroDivisionError: division by zero

# %%
try:
    a = 10 / 0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    a = 10 / 0
except Exception as e:
    print('error in code at line xyz')
    print(e)
# Out:
# error in code at line xyz
# division by zero

# %%
def div(a,b):
    try:
        result = a / b
        print(result)
    except Exception as e:
        print(e)

# %%
div(1,0)
# Out:
# division by zero

# %%
def multiply(a,b):
    try:
        result = a * b
        print(result)
    except Exception as e:
        print(e)

# %%
multiply('Hello', 10+5j)
# Out:
# can't multiply sequence by non-int of type 'complex'

# %%
try:
    logic
except :
    error

# %%
import logging

# %%
logging.basicConfig(level = logging.DEBUG)

# %%
logging.debug('DEBUG LOGGING')
# Out:
# DEBUG:root:DEBUG LOGGING

# %%
logging.info('This is my info log')
logging.warning('Warning log')
logging.critical('This is my critic log')
# Out:
# INFO:root:This is my info log
# WARNING:root:Warning log
# CRITICAL:root:This is my critic log

# %%
import logging
logging.basicConfig(level=logging.ERROR)

try:
    x = 3/0
except Exception as e:
    logging.error(e)
# Out:
# ERROR:root:division by zero

# %%
try:
    a = 10 / 0
except Exception as e:
    print(e)

# %%
import logging
logging.basicConfig(filename='app.log', level=logging.INFO)

logging.info('Project started')
try:
    logging.info('Inside try blog')
    x = 9/0
    logging.info(x)
except Exception as e :
    logging.error(e)
# Out:
# INFO:root:Project started
# INFO:root:Inside try blog
# ERROR:root:division by zero

# %%
str(8/9)
# Out:
# '0.8888888888888888'
