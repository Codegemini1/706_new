# %% [markdown]
# # String

# %%
'Hello'
# Out:
# 'Hello'

# %%
"Hello"
# Out:
# 'Hello'

# %%
print("""This is my first line
This is my second line""")
# Out:
# This is my first line
# This is my second line

# %% [markdown]
# # Boolean

# %% [markdown]
# True / False ---> Outputs

# %%
5 > 8
# Out:
# False

# %%
6 < 0
# Out:
# False

# %%
6 > 1
# Out:
# True

# %%
None

# %% [markdown]
# # Variables

# %%
a = 5

# %%
b = 8

# %%
a+b
# Out:
# 13

# %%
a + b
# Out:
# 13

# %%
1 = 50
# Out:
#   Cell In[12], line 1
#     1 = 50
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a1 = 50

# %%
a_1 = 50

# %%
a1
# Out:
# 50

# %%
a_1
# Out:
# 50

# %%
first name = 'Hello'
# Out:
#   Cell In[17], line 1
#     first name = 'Hello'
#           ^
# SyntaxError: invalid syntax

# %%
first_name = 'hello'

# %%
# type = 60 ---> Not allowed

# %%
type
# Out:
# 60

# %% [markdown]
# # Operations in python

# %%
a = 5

# %%
b = 7

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
a + b # int + int
# Out:
# 12

# %%
c = 1.6

# %%
a
# Out:
# 5

# %%
a + c #int + float
# Out:
# 6.6

# %%
z = 'Hello'

# %%
z
# Out:
# 'Hello'

# %%
a + z # int + str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a + z
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
f = 'Python'

# %%
z
# Out:
# 'Hello'

# %%
f + z # str + str
# Out:
# 'PythonHello'

# %%
'First' + 'Second'
# Out:
# 'FirstSecond'

# %%
a = 'Sham'
b = 'Kumar'

# %%
a + b
# Out:
# 'ShamKumar'

# %%
a + ' ' + b
# Out:
# 'Sham Kumar'

# %%
# F formatting

# %%
age = 50

# %%
print('My age is ', age)
# Out:
# My age is  50

# %%
print(f'My age is : {age}')
# Out:
# My age is : 50

# %%
a
# Out:
# 'Sham'

# %%
mobile = 382378973

# %%
house = 3632

# %%
print(f'My house no is {house} and my mobile number is {mobile}')
# Out:
# My house no is 3632 and my mobile number is 382378973

# %%
name = input('Write your good name')
print(f'Your good name is {name}')
# Out:
# Write your good name sham
# Your good name is sham

# %%
name
# Out:
# 'sham'

# %%
type(name)
# Out:
# str

# %%
age = input('Enter your age')
type(age)
# Out:
# Enter your age 83
# str

# %%
'83'
# Out:
# '83'

# %%
age = int(input('Enter your age'))
type(age)
# Out:
# Enter your age 78
# int

# %% [markdown]
# typecasting ---> Converting one data type into another one

# %%
int('76532567')
# Out:
# 76532567

# %%
int('Hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 int('Hello')
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %%
int('10')
# Out:
# 10

# %%
float('10.4')
# Out:
# 10.4

# %%
height = float(input('Enter your height in feet'))
print(f'Your height is {height} feet')
# Out:
# Enter your height in feet 7.4
# Your height is 7.4 feet

# %%
a = int(input('Enter num 1'))
b = int(input('Enter num 2'))

print(f'Addition of {a} and {b} is {a+b}')
print(f'Sub of {a} and {b} is {a-b}')
print(f'Mul of {a} and {b} is {a*b}')
# Out:
# Enter num 1 5
# Enter num 2 10
# Addition of 5 and 10 is 15
# Sub of 5 and 10 is -5
# Mul of 5 and 10 is 50

# %%
print('Hello' * 3)
# Out:
# HelloHelloHello

# %%
z,o = 10,20

# %%
z
# Out:
# 10

# %%
o
# Out:
# 20

# %%
10 % 2
# Out:
# 0

# %%
10 % 3
# Out:
# 1

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3
