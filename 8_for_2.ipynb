# %%
# sum of numbers

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
total = 0
for i in  range(1,11):
    total = total + i
    print(total,i)
# Out:
# 1 1
# 3 2
# 6 3
# 10 4
# 15 5
# 21 6
# 28 7
# 36 8
# 45 9
# 55 10

# %%
# n(n+1)/2

# %%
n = 10
total = (n*(n+1))/2

# %%
total
# Out:
# 55.0

# %%
n = 721000
total = (n*(n+1))/2
total
# Out:
# 259920860500.0

# %%
for i in range(1,6):
    print('$'*i)
# Out:
# $
# $$
# $$$
# $$$$
# $$$$$

# %%
for i in range(5,0,-1):
    print('$'*i)
# Out:
# $$$$$
# $$$$
# $$$
# $$
# $
