# %% [markdown]
# # Data Types

# %% [markdown]
# # INT

# %% [raw]
# Eg:- Number of family members
# --> 10,5,2,7
# Eg:- Number of bank accounts
# --> 1,3,5,2

# %%
10
# Out:
# 10

# %%
type(10)
# Out:
# int

# %% [markdown]
# # Float

# %% [raw]
# Numbers in decimal format
# Eg: Weight
# --> 43.200
# Eg: Height
# --> 5.8

# %%
5.8
# Out:
# 5.8

# %%
type(5.8)
# Out:
# float

# %% [markdown]
# # Complex

# %% [markdown]
# Vector numbers

# %%
10+5j
# Out:
# (10+5j)

# %%
type(10+5j)
# Out:
# complex
