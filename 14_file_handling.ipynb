# %%
f = open('ipl.txt','w')

# %%
f.write("""The Indian Premier League (IPL) is a premier professional Twenty20 cricket league in India, established by the BCCI in 2008. 
Running annually from March to May, it features ten city-based franchise teams. 
It is one of the world's most lucrative and popular sporting leagues, blending international talent with a high-stakes, rapid tournament format.""")
# Out:
# 351

# %%
f.close()

# %%
f = open('ipl.txt', 'r+')

# %%
f.readline()
# Out:
# 'The Indian Premier League (IPL) is a premier professional Twenty20 cricket league in India, established by the BCCI in 2008. \n'

# %%
f.readline()
# Out:
# 'Running annually from March to May, it features ten city-based franchise teams. \n'

# %%
f.readline()
# Out:
# "It is one of the world's most lucrative and popular sporting leagues, blending international talent with a high-stakes, rapid tournament format."

# %%
f.readline()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['The Indian Premier League (IPL) is a premier professional Twenty20 cricket league in India, established by the BCCI in 2008. \n',
#  'Running annually from March to May, it features ten city-based franchise teams. \n',
#  "It is one of the world's most lucrative and popular sporting leagues, blending international talent with a high-stakes, rapid tournament format."]

# %%
f.seek(0)
# Out:
# 0

# %%
for sen in f.readlines():
    print(sen)
# Out:
# The Indian Premier League (IPL) is a premier professional Twenty20 cricket league in India, established by the BCCI in 2008.
#
# Running annually from March to May, it features ten city-based franchise teams.
#
# It is one of the world's most lucrative and popular sporting leagues, blending international talent with a high-stakes, rapid tournament format.

# %%
f.seek(0)
# Out:
# 0

# %%
words  = []

# %%
t = 'The Indian Premier League (IPL) is a premier professional Twenty20 cricket league in India, established by the BCCI in 2008.'

# %%
t.split(' ')
# Out:
# ['The',
#  'Indian',
#  'Premier',
#  'League',
#  '(IPL)',
#  'is',
#  'a',
#  'premier',
#  'professional',
#  'Twenty20',
#  'cricket',
#  'league',
#  'in',
#  'India,',
#  'established',
#  'by',
#  'the',
#  'BCCI',
#  'in',
#  '2008.']

# %%
for sentence in f.readlines():
    words.extend(sentence.split(' '))

# %%
words
# Out:
# ['The',
#  'Indian',
#  'Premier',
#  'League',
#  '(IPL)',
#  'is',
#  'a',
#  'premier',
#  'professional',
#  'Twenty20',
#  'cricket',
#  'league',
#  'in',
#  'India,',
#  'established',
#  'by',
#  'the',
#  'BCCI',
#  'in',
#  '2008.',
#  '\n',
#  'Running',
#  'annually',
#  'from',
#  'March',
#  'to',
#  'May,',
#  'it',
#  'features',
#  'ten',
#  'city-based',
#  'franchise',
#  'teams.',
#  '\n',
#  'It',
#  'is',
#  'one',
#  'of',
#  'the',
#  "world's",
#  'most',
#  'lucrative',
#  'and',
#  'popular',
#  'sporting',
#  'leagues,',
#  'blending',
#  'international',
#  'talent',
#  'with',
#  'a',
#  'high-stakes,',
#  'rapid',
#  'tournament',
#  'format.']

# %%
words
# Out:
# ['The',
#  'Indian',
#  'Premier',
#  'League',
#  '(IPL)',
#  'is',
#  'a',
#  'premier',
#  'professional',
#  'Twenty20',
#  'cricket',
#  'league',
#  'in',
#  'India,',
#  'established',
#  'by',
#  'the',
#  'BCCI',
#  'in',
#  '2008.',
#  '\n',
#  'Running',
#  'annually',
#  'from',
#  'March',
#  'to',
#  'May,',
#  'it',
#  'features',
#  'ten',
#  'city-based',
#  'franchise',
#  'teams.',
#  '\n',
#  'It',
#  'is',
#  'one',
#  'of',
#  'the',
#  "world's",
#  'most',
#  'lucrative',
#  'and',
#  'popular',
#  'sporting',
#  'leagues,',
#  'blending',
#  'international',
#  'talent',
#  'with',
#  'a',
#  'high-stakes,',
#  'rapid',
#  'tournament',
#  'format.']

# %%
words.count('in')
# Out:
# 2

# %%
# text --> maximum top 3 words

# %%
f.close()

# %%
# create python file

# %%
f = open('function1.py', 'w')

# %%
f.write("""# This is my function1 file
def square(n):
    return n * n
    
def even_odd(n):
    if n % 2 == 0:
        return 'even'
    else:
        return 'odd' """)
# Out:
# 150

# %%
f.close()

# %%
def square(n):
    return n * n

# %%
square(7)
# Out:
# 49
