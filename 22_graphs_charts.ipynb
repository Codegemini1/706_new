# %%
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
students = ['A','B','C','D']
marks = [80,70,90,95]

# %%
plt.bar(students,marks)
plt.title('Student Marks')
plt.ylabel('Marks')
plt.xlabel('Student Name')
plt.show()

# %%
sns.lineplot(x = students, y = marks)
# Out:
# <Axes: >

# %%
plt.bar(students,marks,color='r')
# Out:
# <BarContainer object of 4 artists>

# %%
df.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.scatterplot(data=df, x = 'tip', y = 'total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.relplot(data=df, x = 'tip', y = 'total_bill', hue='smoker')

# %%
sns.relplot(data=df, x = 'tip', y = 'total_bill', hue='time')

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
sns.relplot(data=df, x = 'tip', y = 'total_bill', style='size')

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
sns.relplot(data=df, x = 'tip', y = 'total_bill', style='sex')

# %%
sns.relplot(data=df, x = 'tip', y = 'total_bill', style='day')

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.relplot(data=df, x = 'tip', y = 'total_bill', hue='size')
