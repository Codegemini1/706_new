# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B608-DCBC
#
#  Directory of C:\Users\bhosa\Downloads\706\Advaned Python
#
# 30-04-2026  09:52    <DIR>          .
# 30-04-2026  09:52    <DIR>          ..
# 30-04-2026  09:52    <DIR>          .ipynb_checkpoints
# 30-04-2026  09:52               337 13_file_handling.ipynb
#                1 File(s)            337 bytes
#                3 Dir(s)  27,112,300,544 bytes free

# %%
f = open('hello.txt', 'w')

# %%
f.write('Hello this is my file handling topic.')
# Out:
# 37

# %%
f.close()

# %%
f = open('hello.txt', 'r')

# %%
f.read()
# Out:
# 'Hello this is my file handling topic.'

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Hello this is my file handling topic.'

# %%
f.seek(4)
# Out:
# 4

# %%
f.read()
# Out:
# 'o this is my file handling topic.'

# %%
f.close()

# %%
f = open('goole.txt','r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 f = open('goole.txt','r')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'goole.txt'

# %%
f = open('google.txt','w')

# %%
f.write('This is my first sentence.')
# Out:
# 26

# %%
f.write('This is my second sentence.')
# Out:
# 27

# %%
f.close()

# %%
f = open('google.txt', 'r+') # both read plus write

# %%
f.read()
# Out:
# 'This is my first sentence.This is my second sentence.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.write('hhhh')
# Out:
# 4

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'hhhh is my first sentence.This is my second sentence.'

# %%
f.close()
