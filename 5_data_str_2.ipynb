# %%
t = (1,2,3,4)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 1

# %%
t[0:2]
# Out:
# (1, 2)

# %%
t[0]
# Out:
# 1

# %%
t[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 t[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t
# Out:
# (100, 2, 3, 4)

# %%
g = (0,1,2)

# %%
t + g
# Out:
# (100, 2, 3, 4, 0, 1, 2)

# %% [markdown]
# # tuple ---> changes ---> No

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
t = list(t)

# %%
t
# Out:
# [1, 2, 3, 4]

# %%
type(t)
# Out:
# list

# %%
t[0] = 100

# %%
t
# Out:
# [100, 2, 3, 4]

# %%
t = tuple(t)

# %%
t
# Out:
# (100, 2, 3, 4)

# %%
t.count(2)
# Out:
# 1

# %%
t.count(0)
# Out:
# 0

# %%
t.index(100)
# Out:
# 0

# %% [markdown]
# # Set

# %%
s = {1,1,1,1,2,2,2,3,4,5,5,5}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
d = [1,2,7,88,99,45,34,23,11,99,45,34,12]

# %%
d
# Out:
# [1, 2, 7, 88, 99, 45, 34, 23, 11, 99, 45, 34, 12]

# %%
type(d)
# Out:
# list

# %%
set(d)
# Out:
# {1, 2, 7, 11, 12, 23, 34, 45, 88, 99}

# %%
names = {'om', 'rock', 'sham', 'om', 'rock'}

# %%
names
# Out:
# {'om', 'rock', 'sham'}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(10)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 10}

# %%
s.remove(5)

# %%
s
# Out:
# {1, 2, 3, 4, 10}

# %%
a = {1,2,3}
b = {3,4,5}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5}

# %%
a.intersection(b)
# Out:
# {3}

# %%
a.difference(b)
# Out:
# {1, 2}

# %%
a-b
# Out:
# {1, 2}

# %%
b.difference(a)
# Out:
# {4, 5}

# %%
a
# Out:
# {1, 2, 3}

# %%
a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 a[0]
#
# TypeError: 'set' object is not subscriptable

# %%
# question
3 in a
# Out:
# True

# %%
10 in a
# Out:
# False

# %% [markdown]
# # dict

# %%
d = {'Name':'XYZ', 'Mobile':7236273}

# %%
d
# Out:
# {'Name': 'XYZ', 'Mobile': 7236273}

# %%
type(d)
# Out:
# dict

# %%
d.keys()
# Out:
# dict_keys(['Name', 'Mobile'])

# %%
d.values()
# Out:
# dict_values(['XYZ', 7236273])

# %%
d = {'Names':['A','B','C'], 'Roll_no':(1,2,3), 'Add':{'x','y','z'}}

# %%
d
# Out:
# {'Names': ['A', 'B', 'C'], 'Roll_no': (1, 2, 3), 'Add': {'x', 'y', 'z'}}

# %%
d = {
    'Names':['A','B','C'], 
    'Roll_no':(1,2,3), 
    'Add':{'x','y','z'}
}

# %%
d
# Out:
# {'Names': ['A', 'B', 'C'], 'Roll_no': (1, 2, 3), 'Add': {'x', 'y', 'z'}}

# %%
d[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 d[1]
#
# KeyError: 1

# %%
d['Roll_no']
# Out:
# (1, 2, 3)

# %%
d['Add']  # var['key'] ---> value
# Out:
# {'x', 'y', 'z'}

# %%
d
# Out:
# {'Names': ['A', 'B', 'C'], 'Roll_no': (1, 2, 3), 'Add': {'x', 'y', 'z'}}

# %%
p = {'A':10, 'B':20}

# %%
d + p
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 d + p
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
d | p
# Out:
# {'Names': ['A', 'B', 'C'],
#  'Roll_no': (1, 2, 3),
#  'Add': {'x', 'y', 'z'},
#  'A': 10,
#  'B': 20}
