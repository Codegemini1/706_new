# %%
square(6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 square(6)
#
# NameError: name 'square' is not defined

# %%
import function1

# %%
function1.square(5)
# Out:
# 25

# %%
function1.even_odd(7)
# Out:
# 'odd'

# %%
from new import add

# %%
add(7,8)
# Out:
# 15
